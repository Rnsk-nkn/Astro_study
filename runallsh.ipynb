# %%
inis=["000","001","010","011","100","101","110","111"]
for i in range(8):
    ini=inis[i]
    for j in range(10):
        m=str(j+1)
        m=m.rjust(2, '0')
        #print(i,j)
        #print(ini,m)
        print("cp Input/"+ini+"/M"+m+"/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str"+ini+"M"+m+".dat ; mv glbdsk_dotm.dat  glbdsk_dotm"+ini+"M"+m+".dat" )
# Out:
# cp Input/000/M01/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M01.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M01.dat
# cp Input/000/M02/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M02.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M02.dat
# cp Input/000/M03/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M03.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M03.dat
# cp Input/000/M04/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M04.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M04.dat
# cp Input/000/M05/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M05.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M05.dat
# cp Input/000/M06/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M06.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M06.dat
# cp Input/000/M07/Input_glbdskMdep_tevol ./ ; ./run ; mv glbdsk_str.dat  glbdsk_str000M07.dat ; mv glbdsk_dotm.dat  glbdsk_dotm000M07.dat
# ...
