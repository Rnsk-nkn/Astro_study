# %%
pwd
# Out:
# '/home/porco/mesalowmass/workM01'

# %%
ls LOGS/
# Out:
# history.data         profile1.data  profile4.data  profiles.index
# history.data.pickle  profile2.data  profile5.data
# pgstar.dat           profile3.data  profile6.data

# %%
# Interactive matplotlib plotting for jupyter lab
# %matplotlib inline

# If you use jupyter notebook
# %matplotlib notebook

import matplotlib.pyplot as plt
import mesaPlot as mp
import tulips
from IPython.display import Video

Video("perceived-color-test.mp4", embed=True, width=700, height=600)

# Specify  directory of MESA model
SINGLE_M01_DIR = "/home/porco/mesalowmass/workM01/LOGS/"
SINGLE_M02_DIR = "/home/porco/mesalowmass/workM02/LOGS/"
SINGLE_M03_DIR = "/home/porco/mesalowmass/workM03/LOGS/"
SINGLE_M04_DIR = "/home/porco/mesalowmass/workM04/LOGS/"
SINGLE_M05_DIR = "/home/porco/mesalowmass/workM05/LOGS/"
SINGLE_M06_DIR = "/home/porco/mesalowmass/workM06/LOGS/"
SINGLE_M07_DIR = "/home/porco/mesalowmass/workM07/LOGS/"
SINGLE_M08_DIR = "/home/porco/mesalowmass/workM08/LOGS/"
SINGLE_M09_DIR = "/home/porco/mesalowmass/workM09/LOGS/"
SINGLE_M10_DIR = "/home/porco/mesalowmass/workM10/LOGS/"

m01 = mp.MESA()
m02 = mp.MESA()
m03 = mp.MESA()
m04 = mp.MESA()
m05 = mp.MESA()
m06 = mp.MESA()
m07 = mp.MESA()
m08 = mp.MESA()
m09 = mp.MESA()
m10 = mp.MESA()
m01.loadHistory(filename_in=SINGLE_M01_DIR + "history.data")
m02.loadHistory(filename_in=SINGLE_M02_DIR + "history.data")
m03.loadHistory(filename_in=SINGLE_M03_DIR + "history.data")
m04.loadHistory(filename_in=SINGLE_M04_DIR + "history.data")
m05.loadHistory(filename_in=SINGLE_M05_DIR + "history.data")
m06.loadHistory(filename_in=SINGLE_M06_DIR + "history.data")
m07.loadHistory(filename_in=SINGLE_M07_DIR + "history.data")
m08.loadHistory(filename_in=SINGLE_M08_DIR + "history.data")
m09.loadHistory(filename_in=SINGLE_M09_DIR + "history.data")
m10.loadHistory(filename_in=SINGLE_M10_DIR + "history.data")
tulips.perceived_color(m01, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m02, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m03, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m04, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m05, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m06, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m07, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m08, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m09, time_ind=0, fig_size=(8, 6))
tulips.perceived_color(m10, time_ind=0, fig_size=(8, 6))
plt.show()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Creating animation

# %%
tulips.perceived_color(m10, time_ind=(0, -1, 10), fps=5, output_fname="perceived-color-test")
Video("perceived-color-test.mp4", embed=True, width=700, height=600)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Creating animation
# <video controls  width="700"  height="600">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
