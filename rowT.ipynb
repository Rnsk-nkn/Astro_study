# %%
#%matplotlib nbagg
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
print("start!")
ims = []
dataall=[]
print(dataall)
dataall=np.zeros((4000, 2409))
N = 2409  # 1レコード番号あたりに格納されているデータの数。
M = 4000  # レコードの総数。
numb=1
for i in range(8):
    fol=format(i, '03b')
    #for j in range(10):#mass 01-10
    for j in range(1):#mass 01
        #print(i,j)
        numb+=1
        mass="{0:02d}".format(j+1)
        fname='./glbdsk_str'+fol+"M"+mass+'.dat'
        f = open(fname, 'r')
        dty = np.dtype([('data', '<' + str(N) + 'f')])
        chunk = np.fromfile(f, dtype=dty, count=M)
        data = []
        for k in range(M):
            data.append(chunk[k]['data'])
        data=np.array(data)
        dataall=np.dstack((dataall, data))
print("end")
np.save('dataall_saverhoLd6', dataall)
# Out:
# start!
# []
# end

# %%
#np.save('dataall_save', dataall)
#%matplotlib nbagg
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib as mpl
import multiprocessing as mp
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import gridspec
dataall=np.load('dataall_saverhoLd6.npy')

# %%
#for cond in range(8):#01234567:
plt.cla()
#for cond in [1]:#01234567:
for cond in range(8):#01234567:
    for time in range(10):
        for i in range(1):
            #for M in [0]:
            for M in range(1):
                #k=M+1+(cond*10)
                k=M+1+(cond)
                pltdat=dataall[:,:,k]
                x = []
                y = []
                x.extend(pltdat[:,0])
                y.extend(pltdat[:,302+time*10])
                y=np.array(y)
                
                #y=np.where(y < 1e-8, 1e-30,y)
                test=40
                if M in [0]:
                    print(M,x[test],y[test])
                #for r in range(33):
                #    r=r*20
                #    print(r,x[r])
                if M in [0]:
                    plt.plot(x, y,linewidth = 0.9)
                plt.xscale('log')
                plt.yscale('log')
#plt.xlim(1e-3, 1e+4)
#plt.ylim(1e-18, 1e+9)
                        
    plt.show()
# Out:
# 0 1.0815999507904053 279.25103759765625
# 0 1.0815999507904053 158.81700134277344
# 0 1.0815999507904053 137.1354522705078
# 0 1.0815999507904053 132.21192932128906
# 0 1.0815999507904053 118.14740753173828
# 0 1.0815999507904053 117.6865005493164
# 0 1.0815999507904053 117.57914733886719
# 0 1.0815999507904053 117.5499267578125
# 0 1.0815999507904053 117.54081726074219
# 0 1.0815999507904053 117.53778839111328
# 0 1.0815999507904053 1267.2119140625
# 0 1.0815999507904053 117.53961181640625
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 279.25103759765625
# 0 1.0815999507904053 155.02880859375
# 0 1.0815999507904053 139.3339080810547
# 0 1.0815999507904053 118.65802764892578
# 0 1.0815999507904053 117.6822738647461
# 0 1.0815999507904053 117.55707550048828
# 0 1.0815999507904053 117.53926849365234
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 1267.2119140625
# 0 1.0815999507904053 117.53881072998047
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 279.25103759765625
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 1267.2119140625
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 279.25103759765625
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 1267.2119140625
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078
# 0 1.0815999507904053 117.53766632080078

# %%
#np.save('dataall_save', dataall)
#%matplotlib nbagg
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib as mpl
import multiprocessing as mp
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import gridspec
dataall=np.load('dataall_saverho.npy')
#for cond in range(8):#01234567:
plt.cla()
#for cond in [1]:#01234567:
for cond in range(8):#01234567:
    for time in range(10):
        for i in range(1):
            #for M in [0]:
            for M in range(10):
                k=M+1+(cond*10)
                pltdat=dataall[:,:,k]
                x = []
                y = []
                x.extend(pltdat[:,0])
                y.extend(pltdat[:,330+time])
                y=np.array(y)
                
                #y=np.where(y < 1e-8, 1e-30,y)
                test=40
                #if M in [0]:
                    #print(M,x[test],y[test])
                #for r in range(33):
                #    r=r*20
                #    print(r,x[r])
                if M in [0]:
                    plt.plot(x, y,linewidth = 0.9)
                plt.xscale('log')
                plt.yscale('log')
#plt.xlim(1e-3, 1e+4)
#plt.ylim(1e-18, 1e+9)
                        
plt.show()
