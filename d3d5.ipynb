# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from matplotlib import colors
cm = plt.get_cmap("Blues")
#cm = plt.get_cmap("PRGn")
fanas=np.load('diskdata1.npy')
fdss=fanas.shape
print(fanas.shape)

#fanas10=fanas[:,::40]
fanas10=fanas[:,::200]
fanas10=np.where(fanas10 < 1e-20, 0, fanas10)
print(fanas10.shape)
print(fanas10)
fdss10=(fanas10.shape)

#num=100
num=40
#d3d=np.zeros((num,num,40,2))
d3d=np.zeros((num,num,40,2))
#for r in fanas10[0]:
    #print(r/100)
for x in range(num):
    for y in range(num):
        cent=20
        centy=20
        R=5*((x-cent)**2+(y-cent)**2)**0.5
        #R=((x-cent)**2+(y-cent)**2)**0.5
        #print(np.argmin(np.abs(fanas10[0,:] - R)))
        idx = np.argmin(np.abs(fanas10[0,:] - R)) #Rに一番近いfanas10の添字
        d3d[x,y,centy,0]=idx
        rho=np.log(fanas10[1,idx])+30  
        d3d[x,y,centy,1]=rho  
        #r4=int(R/4)
        r4=int(R/20)
        d3d[x,y,centy-r4:centy+r4,1]=rho
        
        #print(R,idx)
print(d3d.shape)
#print(d3d[:,:,20,1])
#print(d3d[:,:,4,1])


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rhomax=np.max(d3d[:,:,:,1])
for i in range(d3d.shape[0]):
    for j in range(d3d.shape[1]):
        for k in range(d3d.shape[2]):
        #for k in range(1):
            scatter = ax.scatter(i,j,k,c=cm(d3d[i,j,k,1]), s=10,alpha=abs(d3d[i,j,k,1])/(rhomax*(abs(k-20)+1)))
            #scatter = ax.scatter(i,j,1,c=cm(d3d[i,j,k,1]), s=10,alpha=0.3)
            #scatter = ax.scatter(i,j,k,c=cm(0.4))#, s=30,alpha=0.09)
#scatter = ax.scatter(X[0], Y[0], Z[0],color=cm(fanas[0,0,0,0]), cmap='PRGn')
print("scaend")
fig.colorbar(scatter, ax=ax)
#print(np.where(fanas[:,:,:,0] == fanas[:,:,:,0].min()))
#scatter = ax.scatter(x[6], y[1], z[3],c="red", s=50)
plt.show()
# Out:
# (2, 4000)
# (2, 20)
# [[1.59999996e-03 2.54015999e+01 1.00801598e+02 2.26201599e+02
#   4.01601593e+02 6.27001587e+02 9.02401611e+02 1.22780164e+03
#   1.60320166e+03 2.02860156e+03 2.50400171e+03 3.02940161e+03
#   3.60480151e+03 4.23020166e+03 4.90560156e+03 5.63100146e+03
#   6.40640137e+03 7.23180176e+03 8.10720166e+03 9.03260156e+03]
#  [2.76639430e-06 3.86256398e-12 3.98005916e-14 1.85837186e-16
#   2.31905093e-19 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]
# (40, 40, 40, 2)
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from matplotlib import colors
cm = plt.get_cmap("Blues")
#cm = plt.get_cmap("PRGn")
fanas=np.load('diskdata1.npy')
fdss=fanas.shape
print(fanas.shape)

#fanas10=fanas[:,::40]
fanas10=fanas[:,::200]
fanas10=np.where(fanas10 < 1e-20, 0, fanas10)
print(fanas10.shape)
print(fanas10)
fdss10=(fanas10.shape)

#num=100
num=40
#d3d=np.zeros((num,num,40,2))
d3d=np.zeros((num,num,40,2))
#for r in fanas10[0]:
    #print(r/100)
for x in range(num):
    for y in range(num):
        cent=20
        centy=20
        R=3*((x-cent)**2+(y-cent)**2)**0.5
        #R=((x-cent)**2+(y-cent)**2)**0.5
        #print(np.argmin(np.abs(fanas10[0,:] - R)))
        idx = np.argmin(np.abs(fanas10[0,:] - R)) #Rに一番近いfanas10の添字
        d3d[x,y,centy,0]=idx
        rho=np.log(fanas10[1,idx])+30  
        d3d[x,y,centy,1]=rho  
        #r4=int(R/4)
        r4=int(R/20)
        d3d[x,y,centy-r4:centy+r4,1]=rho
        
        #print(R,idx)
print(d3d.shape)
#print(d3d[:,:,20,1])
#print(d3d[:,:,4,1])


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rhomax=np.max(d3d[:,:,:,1])
for i in range(d3d.shape[0]):
    for j in range(d3d.shape[1]):
        for k in range(d3d.shape[2]):
        #for k in range(1):
            scatter = ax.scatter(i,j,k,c=cm(d3d[i,j,k,1]), s=10,alpha=abs(d3d[i,j,k,1])/(rhomax*(abs(k-20)+1)))
            #scatter = ax.scatter(i,j,1,c=cm(d3d[i,j,k,1]), s=10,alpha=0.3)
            #scatter = ax.scatter(i,j,k,c=cm(0.4))#, s=30,alpha=0.09)
#scatter = ax.scatter(X[0], Y[0], Z[0],color=cm(fanas[0,0,0,0]), cmap='PRGn')
print("scaend")
fig.colorbar(scatter, ax=ax)
#print(np.where(fanas[:,:,:,0] == fanas[:,:,:,0].min()))
#scatter = ax.scatter(x[6], y[1], z[3],c="red", s=50)
plt.show()
# Out:
# (2, 4000)
# (2, 20)
# [[1.59999996e-03 2.54015999e+01 1.00801598e+02 2.26201599e+02
#   4.01601593e+02 6.27001587e+02 9.02401611e+02 1.22780164e+03
#   1.60320166e+03 2.02860156e+03 2.50400171e+03 3.02940161e+03
#   3.60480151e+03 4.23020166e+03 4.90560156e+03 5.63100146e+03
#   6.40640137e+03 7.23180176e+03 8.10720166e+03 9.03260156e+03]
#  [2.76639430e-06 3.86256398e-12 3.98005916e-14 1.85837186e-16
#   2.31905093e-19 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]
# (40, 40, 40, 2)
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from matplotlib import colors
cm = plt.get_cmap("Blues")
#cm = plt.get_cmap("PRGn")
fanas=np.load('diskdata1.npy')
fdss=fanas.shape
print(fanas.shape)

#fanas10=fanas[:,::40]
fanas10=fanas[:,::200]
fanas10=np.where(fanas10 < 1e-20, 0, fanas10)
print(fanas10.shape)
print(fanas10)
fdss10=(fanas10.shape)

#num=100
num=40
#d3d=np.zeros((num,num,40,2))
d3d=np.zeros((num,num,40,2))
#for r in fanas10[0]:
    #print(r/100)
for x in range(num):
    for y in range(num):
        cent=20
        centy=20
        R=4*((x-cent)**2+(y-cent)**2)**0.5
        #R=((x-cent)**2+(y-cent)**2)**0.5
        #print(np.argmin(np.abs(fanas10[0,:] - R)))
        idx = np.argmin(np.abs(fanas10[0,:] - R)) #Rに一番近いfanas10の添字
        d3d[x,y,centy,0]=idx
        rho=np.log(fanas10[1,idx])+30  
        d3d[x,y,centy,1]=rho  
        #r4=int(R/4)
        r4=int(R/20)
        d3d[x,y,centy-r4:centy+r4,1]=rho
        
        #print(R,idx)
print(d3d.shape)
#print(d3d[:,:,20,1])
#print(d3d[:,:,4,1])


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rhomax=np.max(d3d[:,:,:,1])
for i in range(d3d.shape[0]):
    for j in range(d3d.shape[1]):
        for k in range(d3d.shape[2]):
        #for k in range(1):
            scatter = ax.scatter(i,j,k,c=cm(d3d[i,j,k,1]), s=10,alpha=abs(d3d[i,j,k,1])/(rhomax*(abs(k-20)+1)*(abs(k-20)+1)))
            #scatter = ax.scatter(i,j,1,c=cm(d3d[i,j,k,1]), s=10,alpha=0.3)
            #scatter = ax.scatter(i,j,k,c=cm(0.4))#, s=30,alpha=0.09)
#scatter = ax.scatter(X[0], Y[0], Z[0],color=cm(fanas[0,0,0,0]), cmap='PRGn')
print("scaend")
fig.colorbar(scatter, ax=ax)
#print(np.where(fanas[:,:,:,0] == fanas[:,:,:,0].min()))
#scatter = ax.scatter(x[6], y[1], z[3],c="red", s=50)
plt.show()
# Out:
# (2, 4000)
# (2, 20)
# [[1.59999996e-03 2.54015999e+01 1.00801598e+02 2.26201599e+02
#   4.01601593e+02 6.27001587e+02 9.02401611e+02 1.22780164e+03
#   1.60320166e+03 2.02860156e+03 2.50400171e+03 3.02940161e+03
#   3.60480151e+03 4.23020166e+03 4.90560156e+03 5.63100146e+03
#   6.40640137e+03 7.23180176e+03 8.10720166e+03 9.03260156e+03]
#  [2.76639430e-06 3.86256398e-12 3.98005916e-14 1.85837186e-16
#   2.31905093e-19 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]
# (40, 40, 40, 2)
# <div id='cdd9056b-0fae-4bcf-9860-2193b8a05805'></div>
# ...
