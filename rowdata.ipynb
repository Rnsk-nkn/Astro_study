# %%
#%matplotlib nbagg
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
print("start!")
ims = []
dataall=[]
print(dataall)
dataall=np.zeros((4000, 2409))
N = 2409  # 1レコード番号あたりに格納されているデータの数。
M = 4000  # レコードの総数。
numb=1
for i in range(8):
    fol=format(i, '03b')
    for j in range(10):
        numb+=1
        mass="{0:02d}".format(j+1)
        fname='./glbdsk_str'+fol+"M"+mass+'.dat'
        f = open(fname, 'r')
        dty = np.dtype([('data', '<' + str(N) + 'f')])
        chunk = np.fromfile(f, dtype=dty, count=M)
        data = []
        for k in range(M):
            data.append(chunk[k]['data'])
        data=np.array(data)
        dataall=np.dstack((dataall, data))
print("end")
np.save('dataall_saverhoLd1', dataall)
# Out:
# start!
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-f05fa740d7d9> in <module>
#      23         data = []
#      24         for k in range(M):
# ---> 25             data.append(chunk[k]['data'])
#      26         data=np.array(data)
#      27         dataall=np.dstack((dataall, data))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
#np.save('dataall_save', dataall)
#%matplotlib nbagg
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib as mpl
import multiprocessing as mp
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import gridspec
dataall=np.load('dataall_saverhoLd3.npy')

# %%
#for cond in range(8):#01234567:
plt.cla()
for cond in [1]:#01234567:
#for cond in range(8):#01234567:
    for time in range(10):
        for i in range(1):
            for M in [0]:
            #for M in range(10):
                k=M+1+(cond*10)
                pltdat=dataall[:,:,k]
                x = []
                y = []
                x.extend(pltdat[:,0])
                y.extend(pltdat[:,603+time])
                y=np.array(y)
                y2=-np.array(y)
                r0=3995
                print(time,y2[r0],y[r0])
                
                #y=np.where(y < 1e-8, 1e-30,y)
                #test=200
                #if M in [1,9]:
                    #print(M,x[test],y[test])
                #for r in range(33):
                #    r=r*20
                #    print(r,x[r])
                plt.plot(x, y,linewidth = 0.9)
                plt.plot(x, y2,linewidth = 0.9,linestyle="dotted")
                plt.xscale('log')
                plt.yscale('log')
#plt.xlim(1e-3, 1e+4)
#plt.ylim(1e-18, 1e+9)
                        
plt.show()
# Out:
# 0 2.39523946507041e-41 -2.39523946507041e-41
# 1 2.39523946507041e-41 -2.39523946507041e-41
# 2 2.39523946507041e-41 -2.39523946507041e-41
# 3 2.39523946507041e-41 -2.39523946507041e-41
# 4 2.39523946507041e-41 -2.39523946507041e-41
# 5 2.39523946507041e-41 -2.39523946507041e-41
# 6 2.39523946507041e-41 -2.39523946507041e-41
# 7 2.39523946507041e-41 -2.39523946507041e-41
# 8 2.39523946507041e-41 -2.39523946507041e-41
# 9 2.39523946507041e-41 -2.39523946507041e-41

# %%
#np.save('dataall_save', dataall)
#%matplotlib nbagg
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib as mpl
import multiprocessing as mp
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import gridspec
dataall=np.load('dataall_saverho.npy')

# %%
#for cond in range(8):#01234567:
plt.cla()
for cond in [1]:#01234567:
#for cond in range(8):#01234567:
    for time in range(1):
        for i in range(1):
            #for M in [0]:
            for M in range(10):
                k=M+1+(cond*10)
                pltdat=dataall[:,:,k]
                x = []
                y = []
                x.extend(pltdat[:,0])
                y.extend(pltdat[:,430])
                y=np.array(y)
                test=200
                if M in [1,9]:
                    print(M,x[test],y[test])
                #y=np.where(y < 1e-8, 1e-30,y)
                #test=38
                #print(x[test],y[test])
                #for r in range(33):
                #    r=r*20
                #    print(r,x[r])
                plt.plot(x, y,linewidth = 0.9)
                plt.xscale('log')
                plt.yscale('log')
#plt.xlim(1e-3, 1e+4)
#plt.ylim(1e-18, 1e+9)
                        
plt.show()
# Out:
# 1 25.401599884033203 36.696285247802734
# 9 25.401599884033203 54.87374496459961

# %%
for M in range(10):
    m=(M+1)/10
    print(M+1,m*0.70)
# Out:
# 1 0.06999999999999999
# 2 0.13999999999999999
# 3 0.21
# 4 0.27999999999999997
# 5 0.35
# 6 0.42
# 7 0.48999999999999994
# 8 0.5599999999999999
# 9 0.63
# 10 0.7

# %%
r:0
Sigma:1-301 [:]
T:302-602 [:]

# %%
 #rhocgs = rhocgs * (stmass)**1.125d0
  #H0a = 4.69d-2  * (stmass**(-0.375d0))
  #sgmcgs = rhocgs * sqrt(pi) * H0a * au
  #sgmcgs = rhocgs * sqrt(pi) * 4.69d-2* ((stmass)**0.75d0 )  *  au
1.125-0.375
# Out:
# 0.75
